# %% [markdown]
# <a href="https://colab.research.google.com/github/Juanseg-martin/Data-Science-I---Serie-A/blob/main/Data_Science_I_Juan_Segundo_Martin.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Importar librerías
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
import warnings

# %%
# Configuraciones opcionales para mejor visualización
sns.set_theme(style="whitegrid") # Establece un tema estético para los gráficos
plt.rcParams['figure.figsize'] = (12, 6) # Establece un tamaño de figura por defecto
warnings.filterwarnings('ignore') # Ignora advertencias (útil para presentaciones)

# %%
import requests

url = "https://github.com/Juanseg-martin/Data-Science-I---Serie-A/raw/refs/heads/main/matches_serie_A.csv"

response = requests.get(url)  # Hace una solicitud GET para obtener el contenido del archivo
print(response.text[:300])  # Imprime los primeros 300 caracteres del archivo para ver cómo está delimitado
# Out:
# Column1;Date;Time;Comp;Round;Day;Venue;Result;GF;GA;Opponent;xG;xGA;Poss;Attendance;Captain;Formation;Opp Formation;Referee;Match Report;Sh;SoT;Dist;FK;PK;PKatt;Season;Team
# 1;18/8/2024;18:30:00;Serie A;Matchweek 1;Sun;Away;L;0;3;Hellas Verona;10;17;670;200270;Giovanni Di Lorenzo;3-4-3;3-4-3;Matteo

# %%
df = pd.read_csv(url, sep=';', encoding='latin-1') # lee el archivo,

df.head()# Muestra las primeras 5 filas
# Out:
#    Column1       Date      Time     Comp        Round  Day Venue Result  GF  \
# 0        1  18/8/2024  18:30:00  Serie A  Matchweek 1  Sun  Away      L   0
# 1        2  25/8/2024  20:45:00  Serie A  Matchweek 2  Sun  Home      W   3
# 2        3  31/8/2024  20:45:00  Serie A  Matchweek 3  Sat  Home      W   2
# 3        4  15/9/2024  18:00:00  Serie A  Matchweek 4  Sun  Away      W   4
# 4        5  21/9/2024  18:00:00  Serie A  Matchweek 5  Sat  Away      D   0
#
#    GA  ...            Referee  Match Report   Sh  SoT   Dist    FK PK PKatt  \
# 0   3  ...   Matteo Marchetti  Match Report  140   40  178.0   0.0  0     0
# 1   0  ...      Luca Pairetto  Match Report  160   50  175.0   0.0  0     0
# 2   1  ...   Paride Tremolada  Match Report  290   70  175.0  10.0  0     0
# 3   0  ...  Federico La Penna  Match Report  130   50  160.0   0.0  0     0
# 4   0  ...     Daniele Doveri  Match Report   80   10  234.0   0.0  0     0
#
#   Season    Team
# 0   2025  Napoli
# 1   2025  Napoli
# 2   2025  Napoli
# 3   2025  Napoli
# 4   2025  Napoli
#
# [5 rows x 28 columns]
